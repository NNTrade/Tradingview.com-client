# %%
import pandas as pd
import warnings
import logging

logging.basicConfig(
    format='\033[93m%(asctime)s %(levelname)s %(name)s:\033[0m %(message)s', level=logging.INFO, datefmt='%I:%M:%S')

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(
    action="ignore", category=pd.errors.SettingWithCopyWarning)

logger = logging.getLogger("1.data_preparation.ipynb")

# %% [markdown]
# # Sectors

# %% [markdown]
# ## Helicopter view

# %%
from src.client.sectors import SectorsSource,MarketEnum

# %%
sectorsSource= SectorsSource.of(MarketEnum.russia)

# %%
sectors_df = sectorsSource.get_overview().loaded_df
sectors_df
# Out:
#                                  Metric currency   Volume / 1D  \
# Id
# SECTOR_RU:COMMERCIAL.SERVICES                RUB  1.268490e+05
# SECTOR_RU:COMMUNICATIONS                     RUB  5.107122e+06
# SECTOR_RU:CONSUMER.DURABLES                  RUB  8.405530e+05
# SECTOR_RU:CONSUMER.NON.DURABLES              RUB  4.327045e+04
# SECTOR_RU:CONSUMER.SERVICES                  RUB  1.192000e+04
# SECTOR_RU:DISTRIBUTION.SERVICES              RUB  2.933370e+05
# SECTOR_RU:ELECTRONIC.TECHNOLOGY              RUB  1.944525e+08
# SECTOR_RU:ENERGY.MINERALS                    RUB  7.884470e+06
# SECTOR_RU:FINANCE                            RUB  5.899299e+09
# SECTOR_RU:HEALTH.SERVICES                    RUB  3.385009e+05
# SECTOR_RU:HEALTH.TECHNOLOGY                  RUB  2.373083e+06
# SECTOR_RU:INDUSTRIAL.SERVICES                RUB  8.581000e+04
# SECTOR_RU:MISCELLANEOUS                      RUB  6.617000e+04
# SECTOR_RU:NON.ENERGY.MINERALS                RUB  4.794626e+06
# SECTOR_RU:PROCESS.INDUSTRIES                 RUB  2.266178e+06
# SECTOR_RU:PRODUCER.MANUFACTURING             RUB  2.596127e+05
# SECTOR_RU:RETAIL.TRADE                       RUB  9.258554e+05
# SECTOR_RU:TECHNOLOGY.SERVICES                RUB  1.403294e+06
# SECTOR_RU:TRANSPORTATION                     RUB  8.452023e+06
# SECTOR_RU:UTILITIES                          RUB  7.279144e+08
#
#                                   Price change/1D mult    Market cap    Type  \
# Id
# SECTOR_RU:COMMERCIAL.SERVICES                 0.002817  7.950726e+08  sector
# SECTOR_RU:COMMUNICATIONS                     -0.004277  1.276050e+12  sector
# SECTOR_RU:CONSUMER.DURABLES                   0.021079  5.811780e+11  sector
# SECTOR_RU:CONSUMER.NON.DURABLES              -0.000811  1.458511e+11  sector
# SECTOR_RU:CONSUMER.SERVICES                  -0.017021  3.013226e+09  sector
# SECTOR_RU:DISTRIBUTION.SERVICES               0.001069  3.352677e+10  sector
# SECTOR_RU:ELECTRONIC.TECHNOLOGY              -0.066340  1.230402e+12  sector
# SECTOR_RU:ENERGY.MINERALS                     0.005238  2.693944e+13  sector
# SECTOR_RU:FINANCE                             0.011241  8.932113e+12  sector
# SECTOR_RU:HEALTH.SERVICES                     0.008798  2.653446e+10  sector
# SECTOR_RU:HEALTH.TECHNOLOGY                  -0.016823  6.626796e+09  sector
# SECTOR_RU:INDUSTRIAL.SERVICES                -0.025763  7.523865e+10  sector
# SECTOR_RU:MISCELLANEOUS                      -0.016835  9.624700e+09  sector
# SECTOR_RU:NON.ENERGY.MINERALS                 0.006023  9.909269e+12  sector
# SECTOR_RU:PROCESS.INDUSTRIES                  0.016885  2.389045e+12  sector
# SECTOR_RU:PRODUCER.MANUFACTURING             -0.004273  5.058552e+11  sector
# SECTOR_RU:RETAIL.TRADE                       -0.002031  1.354154e+12  sector
# SECTOR_RU:TECHNOLOGY.SERVICES                 0.005439  1.001584e+12  sector
# SECTOR_RU:TRANSPORTATION                     -0.006805  1.293630e+12  sector
# SECTOR_RU:UTILITIES                          -0.004991  2.785285e+12  sector
#
#                                              Description  \
# Id
# SECTOR_RU:COMMERCIAL.SERVICES        Commercial Services
# SECTOR_RU:COMMUNICATIONS                  Communications
# SECTOR_RU:CONSUMER.DURABLES            Consumer Durables
# SECTOR_RU:CONSUMER.NON.DURABLES    Consumer Non-Durables
# SECTOR_RU:CONSUMER.SERVICES            Consumer Services
# SECTOR_RU:DISTRIBUTION.SERVICES    Distribution Services
# SECTOR_RU:ELECTRONIC.TECHNOLOGY    Electronic Technology
# SECTOR_RU:ENERGY.MINERALS                Energy Minerals
# SECTOR_RU:FINANCE                                Finance
# SECTOR_RU:HEALTH.SERVICES                Health Services
# SECTOR_RU:HEALTH.TECHNOLOGY            Health Technology
# SECTOR_RU:INDUSTRIAL.SERVICES        Industrial Services
# SECTOR_RU:MISCELLANEOUS                    Miscellaneous
# SECTOR_RU:NON.ENERGY.MINERALS        Non-Energy Minerals
# SECTOR_RU:PROCESS.INDUSTRIES          Process Industries
# SECTOR_RU:PRODUCER.MANUFACTURING  Producer Manufacturing
# SECTOR_RU:RETAIL.TRADE                      Retail Trade
# SECTOR_RU:TECHNOLOGY.SERVICES        Technology Services
# SECTOR_RU:TRANSPORTATION                  Transportation
# SECTOR_RU:UTILITIES                            Utilities
#
#                                  Dividend yield Mult FWD  \
# Id
# SECTOR_RU:COMMERCIAL.SERVICES                       None
# SECTOR_RU:COMMUNICATIONS                            None
# SECTOR_RU:CONSUMER.DURABLES                         None
# SECTOR_RU:CONSUMER.NON.DURABLES                     None
# SECTOR_RU:CONSUMER.SERVICES                         None
# SECTOR_RU:DISTRIBUTION.SERVICES                     None
# SECTOR_RU:ELECTRONIC.TECHNOLOGY                     None
# SECTOR_RU:ENERGY.MINERALS                           None
# SECTOR_RU:FINANCE                                   None
# SECTOR_RU:HEALTH.SERVICES                           None
# SECTOR_RU:HEALTH.TECHNOLOGY                         None
# SECTOR_RU:INDUSTRIAL.SERVICES                       None
# SECTOR_RU:MISCELLANEOUS                             None
# SECTOR_RU:NON.ENERGY.MINERALS                       None
# SECTOR_RU:PROCESS.INDUSTRIES                        None
# SECTOR_RU:PRODUCER.MANUFACTURING                    None
# SECTOR_RU:RETAIL.TRADE                              None
# SECTOR_RU:TECHNOLOGY.SERVICES                       None
# SECTOR_RU:TRANSPORTATION                            None
# SECTOR_RU:UTILITIES                                 None
#
#                                                     Name Market country  \
# Id
# SECTOR_RU:COMMERCIAL.SERVICES        commercial-services         russia
# SECTOR_RU:COMMUNICATIONS                  communications         russia
# SECTOR_RU:CONSUMER.DURABLES            consumer-durables         russia
# SECTOR_RU:CONSUMER.NON.DURABLES    consumer-non-durables         russia
# SECTOR_RU:CONSUMER.SERVICES            consumer-services         russia
# SECTOR_RU:DISTRIBUTION.SERVICES    distribution-services         russia
# SECTOR_RU:ELECTRONIC.TECHNOLOGY    electronic-technology         russia
# SECTOR_RU:ENERGY.MINERALS                energy-minerals         russia
# SECTOR_RU:FINANCE                                finance         russia
# SECTOR_RU:HEALTH.SERVICES                health-services         russia
# SECTOR_RU:HEALTH.TECHNOLOGY            health-technology         russia
# SECTOR_RU:INDUSTRIAL.SERVICES        industrial-services         russia
# SECTOR_RU:MISCELLANEOUS                    miscellaneous         russia
# SECTOR_RU:NON.ENERGY.MINERALS        non-energy-minerals         russia
# SECTOR_RU:PROCESS.INDUSTRIES          process-industries         russia
# SECTOR_RU:PRODUCER.MANUFACTURING  producer-manufacturing         russia
# SECTOR_RU:RETAIL.TRADE                      retail-trade         russia
# SECTOR_RU:TECHNOLOGY.SERVICES        technology-services         russia
# SECTOR_RU:TRANSPORTATION                  transportation         russia
# SECTOR_RU:UTILITIES                            utilities         russia
#
#                                   Stocks  Industries
# Id
# SECTOR_RU:COMMERCIAL.SERVICES          1           1
# SECTOR_RU:COMMUNICATIONS               8           3
# SECTOR_RU:CONSUMER.DURABLES            7           3
# SECTOR_RU:CONSUMER.NON.DURABLES        3           2
# SECTOR_RU:CONSUMER.SERVICES            1           1
# SECTOR_RU:DISTRIBUTION.SERVICES        1           1
# SECTOR_RU:ELECTRONIC.TECHNOLOGY        6           2
# SECTOR_RU:ENERGY.MINERALS             17           4
# SECTOR_RU:FINANCE                     23           9
# SECTOR_RU:HEALTH.SERVICES              3           2
# SECTOR_RU:HEALTH.TECHNOLOGY            3           3
# SECTOR_RU:INDUSTRIAL.SERVICES          1           1
# SECTOR_RU:MISCELLANEOUS               24           1
# SECTOR_RU:NON.ENERGY.MINERALS         24           4
# SECTOR_RU:PROCESS.INDUSTRIES          10           4
# SECTOR_RU:PRODUCER.MANUFACTURING      11           5
# SECTOR_RU:RETAIL.TRADE                 8           5
# SECTOR_RU:TECHNOLOGY.SERVICES          6           2
# SECTOR_RU:TRANSPORTATION               9           5
# SECTOR_RU:UTILITIES                   50           3

# %% [markdown]
# ## Sector

# %%
sector = sectorsSource.get_sector(sectors_df.loc["SECTOR_RU:COMMERCIAL.SERVICES"])

# %%
sector.get_industries().loaded_df
# Out:
#                                                    Metric currency  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...             RUB
#
#                                                     Volume / 1D  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...       126849
#
#                                                     Price change/1D mult  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...              0.002817
#
#                                                     Market cap      Type  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...   795072600  industry
#
#                                                                           Description  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...  Miscellaneous Commercial Services
#
#                                                    Dividend yield Mult FWD  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...                    None
#
#                                                                                  Name  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...  miscellaneous-commercial-services
#
#                                                    Market country  Stocks  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...         russia       1
#
#                                                                  Sector
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...  Commercial Services

# %%
sector.get_stocks().loaded_df
# Out:
#           Metric currency  Volume / 1D  Price change/1D mult  Market cap  \
# Id
# MOEX:SVET             RUB       126849              0.002817   795072600
#
#             Type     Description Dividend yield Mult TTM  \
# Id
# MOEX:SVET  stock  Svetofor Group                    None
#
#           Dividend yield Mult FWD Price/BookRatio  Name  ...  \
# Id                                                       ...
# MOEX:SVET                    None            None  SVET  ...
#
#            Price decimal Len  Currency Change in Cur / 1D  \
# Id
# MOEX:SVET                100       RUB                0.1
#
#            Volume * Price / 1D  Price/EarningPerShare BasicEarningPerShare  \
# Id
# MOEX:SVET            4515824.4                   None                 None
#
#           Dividend/Share               Sector  \
# Id
# MOEX:SVET           None  Commercial Services
#
#                                     Industry Market
# Id
# MOEX:SVET  Miscellaneous Commercial Services   MOEX
#
# [1 rows x 21 columns]

# %% [markdown]
# # Industry

# %% [markdown]
# ## Helicopter view

# %%
industies_df = sector.get_industries().loaded_df
industies_df
# Out:
#                                                    Metric currency  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...             RUB
#
#                                                     Volume / 1D  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...       126849
#
#                                                     Price change/1D mult  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...              0.002817
#
#                                                     Market cap      Type  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...   795072600  industry
#
#                                                                           Description  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...  Miscellaneous Commercial Services
#
#                                                    Dividend yield Mult FWD  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...                    None
#
#                                                                                  Name  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...  miscellaneous-commercial-services
#
#                                                    Market country  Stocks  \
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...         russia       1
#
#                                                                  Sector
# Id
# INDUSTRY_RU:COMMERCIAL.SERVICES.MISCELLANEOUS.C...  Commercial Services

# %% [markdown]
# # Get Industry

# %%
industry = sector.get_industry(industies_df.iloc[0])
industry.get_stocks().loaded_df
# Out:
#           Metric currency  Volume / 1D  Price change/1D mult  Market cap  \
# Id
# MOEX:SVET             RUB       126849              0.002817   795072600
#
#             Type     Description Dividend yield Mult TTM  \
# Id
# MOEX:SVET  stock  Svetofor Group                    None
#
#           Dividend yield Mult FWD Price/BookRatio  Name  ...  \
# Id                                                       ...
# MOEX:SVET                    None            None  SVET  ...
#
#            Price decimal Len  Currency Change in Cur / 1D  \
# Id
# MOEX:SVET                100       RUB                0.1
#
#            Volume * Price / 1D  Price/EarningPerShare BasicEarningPerShare  \
# Id
# MOEX:SVET            4515824.4                   None                 None
#
#           Dividend/Share               Sector  \
# Id
# MOEX:SVET           None  Commercial Services
#
#                                     Industry Market
# Id
# MOEX:SVET  Miscellaneous Commercial Services   MOEX
#
# [1 rows x 21 columns]

# %% [markdown]
# # Stocks

# %%
from src.client.stocks import StockSource

# %%
stock_df = StockSource.of(MarketEnum.russia).get_overview().loaded_df
stock_df
# Out:
# 10:26:49 WARNING Response: Not all records has been loaded. Loaded 100 records of 261
#           Metric currency  Volume / 1D  Price change/1D mult    Market cap  \
# Id
# MOEX:ABIO             RUB       796480             -0.003376  1.094143e+10
# MOEX:ABRD             RUB        78200             -0.006443  3.022326e+10
# MOEX:AFKS             RUB     22783900              0.004733  1.684504e+11
# MOEX:AFLT             RUB      4107880              0.004450  1.608199e+11
# MOEX:AGRO             RUB       108114              0.003992  5.747469e+10
# ...                   ...          ...                   ...           ...
# MOEX:LENT             RUB         9105             -0.002078  8.356733e+10
# MOEX:LIFE             RUB      4715200             -0.010149  3.221488e+09
# MOEX:LKOH             RUB       786722              0.011233  4.693819e+12
# MOEX:LNZL             RUB         4011              0.003382  2.139607e+10
# MOEX:LPSB             RUB       257300             -0.078554  5.746536e+09
#
#             Type               Description  Dividend yield Mult TTM  \
# Id
# MOEX:ABIO  stock                    ARTGEN                      NaN
# MOEX:ABRD  stock               Abrau-Durso                      NaN
# MOEX:AFKS  stock               AFK Sistema                      NaN
# MOEX:AFLT  stock                  Aeroflot                      NaN
# MOEX:AGRO     dr  GDR ROS AGRO PLC ORD SHS                      0.0
# ...          ...                       ...                      ...
# MOEX:LENT  stock       Lenta IPJSC ORD SHS                      NaN
# MOEX:LIFE  stock                Farmsintez                      NaN
# MOEX:LKOH  stock                    LUKOIL                      NaN
# MOEX:LNZL  stock                 Lenzoloto                      NaN
# MOEX:LPSB  stock                      LESK                      NaN
#
#           Dividend yield Mult FWD  Price/BookRatio  Name  ...  \
# Id                                                        ...
# MOEX:ABIO                    None        22.988640  ABIO  ...
# MOEX:ABRD                    None              NaN  ABRD  ...
# MOEX:AFKS                    None              NaN  AFKS  ...
# MOEX:AFLT                    None              NaN  AFLT  ...
# MOEX:AGRO                    None         0.930799  AGRO  ...
# ...                           ...              ...   ...  ...
# MOEX:LENT                    None              NaN  LENT  ...
# MOEX:LIFE                    None              NaN  LIFE  ...
# MOEX:LKOH                    None              NaN  LKOH  ...
# MOEX:LNZL                    None              NaN  LNZL  ...
# MOEX:LPSB                    None              NaN  LPSB  ...
#
#            Price decimal Len  Currency Change in Cur / 1D  \
# Id
# MOEX:ABIO                100       RUB             -0.400
# MOEX:ABRD                 10       RUB             -2.000
# MOEX:AFKS               1000       RUB              0.082
# MOEX:AFLT                100       RUB              0.180
# MOEX:AGRO                 10       RUB              4.600
# ...                      ...       ...                ...
# MOEX:LENT                 10       RUB             -1.500
# MOEX:LIFE               1000       RUB             -0.075
# MOEX:LKOH                 10       RUB             75.500
# MOEX:LNZL                  1       RUB             60.000
# MOEX:LPSB                100       RUB             -3.150
#
#            Volume * Price / 1D  Price/EarningPerShare  BasicEarningPerShare  \
# Id
# MOEX:ABIO         9.406429e+07             171.632030              0.688100
# MOEX:ABRD         2.411688e+07                    NaN                   NaN
# MOEX:AFKS         3.965993e+08                    NaN                   NaN
# MOEX:AFLT         1.669032e+08                    NaN                   NaN
# MOEX:AGRO         1.250879e+08               6.362054            181.859511
# ...                        ...                    ...                   ...
# MOEX:LENT         6.560152e+06                    NaN                   NaN
# MOEX:LIFE         3.449169e+07                    NaN                   NaN
# MOEX:LKOH         5.347349e+09                    NaN                   NaN
# MOEX:LNZL         7.139580e+07                    NaN                   NaN
# MOEX:LPSB         9.507235e+06                    NaN                   NaN
#
#            Dividend/Share                 Sector  \
# Id
# MOEX:ABIO             0.0        Health Services
# MOEX:ABRD             NaN  Consumer Non-Durables
# MOEX:AFKS             NaN         Communications
# MOEX:AFLT             NaN         Transportation
# MOEX:AGRO             0.0     Process Industries
# ...                   ...                    ...
# MOEX:LENT             0.0           Retail Trade
# MOEX:LIFE             NaN      Health Technology
# MOEX:LKOH             NaN        Energy Minerals
# MOEX:LNZL             NaN    Non-Energy Minerals
# MOEX:LPSB             NaN              Utilities
#
#                                    Industry Market
# Id
# MOEX:ABIO          Medical/Nursing Services   MOEX
# MOEX:ABRD              Beverages: Alcoholic   MOEX
# MOEX:AFKS       Wireless Telecommunications   MOEX
# MOEX:AFLT                          Airlines   MOEX
# MOEX:AGRO  Agricultural Commodities/Milling   MOEX
# ...                                     ...    ...
# MOEX:LENT                       Food Retail   MOEX
# MOEX:LIFE            Pharmaceuticals: Major   MOEX
# MOEX:LKOH            Oil Refining/Marketing   MOEX
# MOEX:LNZL                   Precious Metals   MOEX
# MOEX:LPSB                Electric Utilities   MOEX
#
# [100 rows x 21 columns]
