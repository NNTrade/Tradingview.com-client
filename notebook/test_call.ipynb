# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
file_path = "./test/parser/mocks/industry_request_response.html"
with open(file_path, 'r') as file:
    test_response = file.read()

# %%
from src.parser._parse_tools import get_soup_from_payload, parse_header_from_soup, parse_cells_from_soup

# %%
soup = get_soup_from_payload(test_response)
cols = parse_header_from_soup(soup)
rows = parse_cells_from_soup(soup)

cells_df = pd.DataFrame(rows, columns=cols)
cells_df
# Out:
#                                              Industry  \
# 0   [ , [Advertising/Marketing                    ...
# 1   [ , [Aerospace                                ...
# 2   [ , [Agricultural                             ...
# 3   [ , [Air                                      ...
# 4                                  [ , [Airlines],  ]
# ..                                                ...
# 95  [ , [Other                                    ...
# 96  [ , [Other                                    ...
# 97  [ , [Packaged                                 ...
# 98  [ , [Personnel                                ...
# 99  [ , [Pharmaceuticals:                         ...
#
#                                            Market cap Dividend yield FWD %  \
# 0   [                                    53.481B, ...      [ , [2.92%],  ]
# 1   [                                    940.916B,...      [ , [1.44%],  ]
# 2   [                                    77.404B, ...      [ , [2.59%],  ]
# 3   [                                    268.666B,...      [ , [2.76%],  ]
# 4   [                                    120.739B,...      [ , [0.47%],  ]
# ..                                                ...                  ...
# 95  [                                    266.408B,...      [ , [4.43%],  ]
# 96  [                                    180.41B, ...      [ , [0.92%],  ]
# 97  [                                    5.51T, [ ...      [ , [0.59%],  ]
# 98  [                                    34.117B, ...      [ , [1.63%],  ]
# 99  [                                    13.891B, ...                  [—]
#
#          Change % 1D                                     Volume 1D  \
# 0    [ , [0.71%],  ]                                      [1.807M]
# 1    [ , [0.57%],  ]                                      [2.371M]
# 2    [ , [0.71%],  ]                                      [2.068M]
# 3    [ , [0.55%],  ]                                      [2.084M]
# 4    [ , [1.81%],  ]                                      [7.589M]
# ..               ...                                           ...
# 95  [ , [−0.47%],  ]                                          [4M]
# 96   [ , [1.07%],  ]                                      [9.004M]
# 97   [ , [1.95%],  ]   [15.749M                                  ]
# 98   [ , [0.68%],  ]  [405.595K                                  ]
# 99  [ , [−0.20%],  ]                                      [4.932M]
#
#                                                Sector Stocks
# 0   [[Commercial                                  ...   [36]
# 1   [[Electronic                                  ...   [64]
# 2   [[Process                                     ...   [32]
# 3                               [[Transportation],  ]   [19]
# 4                               [[Transportation],  ]   [22]
# ..                                                ...    ...
# 95  [[Non-Energy                                  ...   [47]
# 96                              [[Transportation],  ]   [21]
# 97  [[Technology                                  ...  [361]
# 98  [[Commercial                                  ...   [28]
# 99  [[Health                                      ...    [3]
#
# [100 rows x 7 columns]

# %%
cells_df.applymap(lambda el: el.text.strip())
# Out:
#                                              Industry    Market cap  \
# 0   Advertising/Marketing                         ...   53.481B USD
# 1   Aerospace                                     ...  940.916B USD
# 2   Agricultural                                  ...   77.404B USD
# 3   Air                                      Freig...  268.666B USD
# 4                                            Airlines  120.739B USD
# ..                                                ...           ...
# 95  Other                                      Met...  266.408B USD
# 96  Other                                      Tra...   180.41B USD
# 97  Packaged                                      ...     5.51T USD
# 98  Personnel                                     ...   34.117B USD
# 99  Pharmaceuticals:                              ...   13.891B USD
#
#    Dividend yield FWD % Change % 1D Volume 1D  \
# 0                 2.92%       0.71%    1.807M
# 1                 1.44%       0.57%    2.371M
# 2                 2.59%       0.71%    2.068M
# 3                 2.76%       0.55%    2.084M
# 4                 0.47%       1.81%    7.589M
# ..                  ...         ...       ...
# 95                4.43%      −0.47%        4M
# 96                0.92%       1.07%    9.004M
# 97                0.59%       1.95%   15.749M
# 98                1.63%       0.68%  405.595K
# 99                    —      −0.20%    4.932M
#
#                                                Sector Stocks
# 0   Commercial                                    ...     36
# 1   Electronic                                    ...     64
# 2   Process                                      I...     32
# 3                                      Transportation     19
# 4                                      Transportation     22
# ..                                                ...    ...
# 95  Non-Energy                                    ...     47
# 96                                     Transportation     21
# 97  Technology                                    ...    361
# 98  Commercial                                    ...     28
# 99  Health                                      Te...      3
#
# [100 rows x 7 columns]

# %%
cells_df[["Industry","Sector"]].applymap(lambda el: el.find('a')['href'])
# Out:
#                                              Industry  \
# 0   /markets/stocks-usa/sectorandindustry-industry...
# 1   /markets/stocks-usa/sectorandindustry-industry...
# 2   /markets/stocks-usa/sectorandindustry-industry...
# 3   /markets/stocks-usa/sectorandindustry-industry...
# 4   /markets/stocks-usa/sectorandindustry-industry...
# ..                                                ...
# 95  /markets/stocks-usa/sectorandindustry-industry...
# 96  /markets/stocks-usa/sectorandindustry-industry...
# 97  /markets/stocks-usa/sectorandindustry-industry...
# 98  /markets/stocks-usa/sectorandindustry-industry...
# 99  /markets/stocks-usa/sectorandindustry-industry...
#
#                                                Sector
# 0   /markets/stocks-usa/sectorandindustry-sector/c...
# 1   /markets/stocks-usa/sectorandindustry-sector/e...
# 2   /markets/stocks-usa/sectorandindustry-sector/p...
# 3   /markets/stocks-usa/sectorandindustry-sector/t...
# 4   /markets/stocks-usa/sectorandindustry-sector/t...
# ..                                                ...
# 95  /markets/stocks-usa/sectorandindustry-sector/n...
# 96  /markets/stocks-usa/sectorandindustry-sector/t...
# 97  /markets/stocks-usa/sectorandindustry-sector/t...
# 98  /markets/stocks-usa/sectorandindustry-sector/c...
# 99  /markets/stocks-usa/sectorandindustry-sector/h...
#
# [100 rows x 2 columns]

# %%
from src.parser.industry_parser import industry_response_parse

# %%
industry_response_parse(test_response)
# Out:
#                                     Market cap  Dividend yield FWD rel  \
# Industry
# Advertising/Marketing Services    5.348100e+10                  0.0292
# Aerospace & Defense               9.409160e+11                  0.0144
# Agricultural Commodities/Milling  7.740400e+10                  0.0259
# Air Freight/Couriers              2.686660e+11                  0.0276
# Airlines                          1.207390e+11                  0.0047
# ...                                        ...                     ...
# Other Metals/Minerals             2.664080e+11                  0.0443
# Other Transportation              1.804100e+11                  0.0092
# Packaged Software                 5.510000e+12                  0.0059
# Personnel Services                3.411700e+10                  0.0163
# Pharmaceuticals: Generic          1.389100e+10                     NaN
#
#                                   Change rel 1D   Volume 1D  \
# Industry
# Advertising/Marketing Services           0.0071   1807000.0
# Aerospace & Defense                      0.0057   2371000.0
# Agricultural Commodities/Milling         0.0071   2068000.0
# Air Freight/Couriers                     0.0055   2084000.0
# Airlines                                 0.0181   7589000.0
# ...                                         ...         ...
# Other Metals/Minerals                   -0.0047   4000000.0
# Other Transportation                     0.0107   9004000.0
# Packaged Software                        0.0195  15749000.0
# Personnel Services                       0.0068    405595.0
# Pharmaceuticals: Generic                -0.0020   4932000.0
#
#                                                  Sector  Stocks  \
# Industry
# Advertising/Marketing Services      Commercial Services    36.0
# Aerospace & Defense               Electronic Technology    64.0
# Agricultural Commodities/Milling     Process Industries    32.0
# Air Freight/Couriers                     Transportation    19.0
# Airlines                                 Transportation    22.0
# ...                                                 ...     ...
# Other Metals/Minerals               Non-Energy Minerals    47.0
# Other Transportation                     Transportation    21.0
# Packaged Software                   Technology Services   361.0
# Personnel Services                  Commercial Services    28.0
# Pharmaceuticals: Generic              Health Technology     3.0
#
#                                  Market cap currency  \
# Industry
# Advertising/Marketing Services                   USD
# Aerospace & Defense                              USD
# Agricultural Commodities/Milling                 USD
# Air Freight/Couriers                             USD
# Airlines                                         USD
# ...                                              ...
# Other Metals/Minerals                            USD
# Other Transportation                             USD
# Packaged Software                                USD
# Personnel Services                               USD
# Pharmaceuticals: Generic                         USD
#
#                                                                        Industry URL  \
# Industry
# Advertising/Marketing Services    /markets/stocks-usa/sectorandindustry-industry...
# Aerospace & Defense               /markets/stocks-usa/sectorandindustry-industry...
# Agricultural Commodities/Milling  /markets/stocks-usa/sectorandindustry-industry...
# Air Freight/Couriers              /markets/stocks-usa/sectorandindustry-industry...
# Airlines                          /markets/stocks-usa/sectorandindustry-industry...
# ...                                                                             ...
# Other Metals/Minerals             /markets/stocks-usa/sectorandindustry-industry...
# Other Transportation              /markets/stocks-usa/sectorandindustry-industry...
# Packaged Software                 /markets/stocks-usa/sectorandindustry-industry...
# Personnel Services                /markets/stocks-usa/sectorandindustry-industry...
# Pharmaceuticals: Generic          /markets/stocks-usa/sectorandindustry-industry...
#
#                                                                          Sector URL
# Industry
# Advertising/Marketing Services    /markets/stocks-usa/sectorandindustry-sector/c...
# Aerospace & Defense               /markets/stocks-usa/sectorandindustry-sector/e...
# Agricultural Commodities/Milling  /markets/stocks-usa/sectorandindustry-sector/p...
# Air Freight/Couriers              /markets/stocks-usa/sectorandindustry-sector/t...
# Airlines                          /markets/stocks-usa/sectorandindustry-sector/t...
# ...                                                                             ...
# Other Metals/Minerals             /markets/stocks-usa/sectorandindustry-sector/n...
# Other Transportation              /markets/stocks-usa/sectorandindustry-sector/t...
# Packaged Software                 /markets/stocks-usa/sectorandindustry-sector/t...
# Personnel Services                /markets/stocks-usa/sectorandindustry-sector/c...
# Pharmaceuticals: Generic          /markets/stocks-usa/sectorandindustry-sector/h...
#
# [100 rows x 9 columns]

# %%
from src.api.scan_api import post_scan

# %%
industries_columns = ["description",
                      "market",
                      "market_cap_basic",
                      "type",
                      "typespecs",
                      "fundamental_currency_code",
                      "dividends_yield",
                      "change",
                      "volume",
                      "sector",
                      "basic_elements"]

# %%
top_order = industries_columns[0]
response_json = post_scan(industries_columns, 5, 0, top_order, True)
print(response_json)
# Out:
# {'totalCount': 18359, 'data': [{'s': 'AMEX:ZIVB', 'd': ['-1x Short VIX Mid-Term Futures Strategy ETF -1x Short VIX Mid-Term Futures Strategy ETF', 'america', None, 'fund', ['etf'], 'USD', None, -0.04745759, 6465, 'Miscellaneous', None]}, {'s': 'OTC:OONEF', 'd': ['01 Communique Lab Inc.', 'america', 6350424.14454546, 'stock', ['common'], 'USD', None, -28.26039626, 8750, 'Technology Services', None]}, {'s': 'NASDAQ:FLWS', 'd': ['1-800-FLOWERS.COM, Inc.', 'america', 524038586.5329114, 'stock', ['common'], 'USD', None, 2.40506329, 540177, 'Retail Trade', None]}, {'s': 'NASDAQ:VCXA', 'd': ['10X Capital Venture Acquisition Corp. II', 'america', 121549392.98333333, 'stock', ['common'], 'USD', None, 0.34313725, 1934, 'Finance', None]}, {'s': 'NASDAQ:VCXAU', 'd': ['10X Capital Venture Acquisition Corp. II', 'america', 121133738, 'fund', ['unit'], 'USD', None, -0.14691479, 2795, 'Finance', None]}]}

# %%
from src.parser.scan_json_parser import scan_json_parse

# %%
df = scan_json_parse(industries_columns, response_json)
df
# Out:
#                                                     description   market  \
# Id
# AMEX:ZIVB     -1x Short VIX Mid-Term Futures Strategy ETF -1...  america
# OTC:OONEF                                01 Communique Lab Inc.  america
# NASDAQ:FLWS                             1-800-FLOWERS.COM, Inc.  america
# NASDAQ:VCXA            10X Capital Venture Acquisition Corp. II  america
# NASDAQ:VCXAU           10X Capital Venture Acquisition Corp. II  america
#
#               market_cap_basic   type typespecs fundamental_currency_code  \
# Id
# AMEX:ZIVB                  NaN   fund     [etf]                       USD
# OTC:OONEF         6.350424e+06  stock  [common]                       USD
# NASDAQ:FLWS       5.240386e+08  stock  [common]                       USD
# NASDAQ:VCXA       1.215494e+08  stock  [common]                       USD
# NASDAQ:VCXAU      1.211337e+08   fund    [unit]                       USD
#
#              dividends_yield     change  volume               sector  \
# Id
# AMEX:ZIVB               None  -0.047458    6465        Miscellaneous
# OTC:OONEF               None -28.260396    8750  Technology Services
# NASDAQ:FLWS             None   2.405063  540177         Retail Trade
# NASDAQ:VCXA             None   0.343137    1934              Finance
# NASDAQ:VCXAU            None  -0.146915    2795              Finance
#
#              basic_elements
# Id
# AMEX:ZIVB              None
# OTC:OONEF              None
# NASDAQ:FLWS            None
# NASDAQ:VCXA            None
# NASDAQ:VCXAU           None

# %%
df.rename(columns={"dsds":"1212"})
# Out:
#                                                     description   market  \
# Id
# AMEX:ZIVB     -1x Short VIX Mid-Term Futures Strategy ETF -1...  america
# OTC:OONEF                                01 Communique Lab Inc.  america
# NASDAQ:FLWS                             1-800-FLOWERS.COM, Inc.  america
# NASDAQ:VCXA            10X Capital Venture Acquisition Corp. II  america
# NASDAQ:VCXAU           10X Capital Venture Acquisition Corp. II  america
#
#               market_cap_basic   type typespecs fundamental_currency_code  \
# Id
# AMEX:ZIVB                  NaN   fund     [etf]                       USD
# OTC:OONEF         6.350424e+06  stock  [common]                       USD
# NASDAQ:FLWS       5.240386e+08  stock  [common]                       USD
# NASDAQ:VCXA       1.215494e+08  stock  [common]                       USD
# NASDAQ:VCXAU      1.211337e+08   fund    [unit]                       USD
#
#              dividends_yield     change  volume               sector  \
# Id
# AMEX:ZIVB               None  -0.047458    6465        Miscellaneous
# OTC:OONEF               None -28.260396    8750  Technology Services
# NASDAQ:FLWS             None   2.405063  540177         Retail Trade
# NASDAQ:VCXA             None   0.343137    1934              Finance
# NASDAQ:VCXAU            None  -0.146915    2795              Finance
#
#              basic_elements
# Id
# AMEX:ZIVB              None
# OTC:OONEF              None
# NASDAQ:FLWS            None
# NASDAQ:VCXA            None
# NASDAQ:VCXAU           None

# %%
from src.api.symbol_query_types import SymbolQueryTypes

# %%
SymbolQueryTypes("sector").value
# Out:
# 'sector'
