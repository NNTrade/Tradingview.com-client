# %%
import logging

logging.basicConfig(format='\033[93m%(asctime)s %(levelname)s %(name)s:\033[0m %(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

import warnings
import pandas as pd

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.simplefilter(action="ignore", category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# # USA stock market

# %%
from src.client.usa_stock_market.columns import Column, to_df

# %% [markdown]
# ## Columns

# %%
col_df = to_df(Column.all_column_info())
col_df
# Out:
#                                                 Output name  \
# ENUM
# Column.TradedCap                        Volume * Price / 1D
# Column.stocks                                        Stocks
# Column.price_change_per_1d             Price change/1D mult
# Column.price_change_abs                  Change in Cur / 1D
# Column.close                                          Close
# Column.currency                                    Currency
# Column.description                              Description
# Column.dividends_yield_fwd          Dividend yield Mult FWD
# Column.dividends_yield_current      Dividend yield Mult TTM
# Column.dividend_per_share                    Dividend/Share
# Column.earnings_per_share              BasicEarningPerShare
# Column.cnt_industries                            Industries
# Column.market                                        Market
# Column.metric_cur                           Metric currency
# Column.industry                                    Industry
# Column.market_country                        Market country
# Column.market_cap                                Market cap
# Column.el_name                                         Name
# Column.price_vs_bookratio                   Price/BookRatio
# Column.price_vs_earnings_per_share    Price/EarningPerShare
# Column.price_dec_len                      Price decimal Len
# Column.sector                                        Sector
# Column.type                                            Type
# Column.volume                                   Volume / 1D
#
#                                                          Tech name  \
# ENUM
# Column.TradedCap                                      Value.Traded
# Column.stocks                                       basic_elements
# Column.price_change_per_1d                                  change
# Column.price_change_abs                                 change_abs
# Column.close                                                 close
# Column.currency                                           currency
# Column.description                                     description
# Column.dividends_yield_fwd                         dividends_yield
# Column.dividends_yield_current             dividends_yield_current
# Column.dividend_per_share           dps_common_stock_prim_issue_fy
# Column.earnings_per_share             earnings_per_share_basic_ttm
# Column.cnt_industries                                     elements
# Column.market                                             exchange
# Column.metric_cur                        fundamental_currency_code
# Column.industry                                           industry
# Column.market_country                                       market
# Column.market_cap                                 market_cap_basic
# Column.el_name                                                name
# Column.price_vs_bookratio                            price_book_fq
# Column.price_vs_earnings_per_share              price_earnings_ttm
# Column.price_dec_len                                    pricescale
# Column.sector                                               sector
# Column.type                                                   type
# Column.volume                                               volume
#
#                                                                           Description  \
# ENUM
# Column.TradedCap                                               Capital traded / 1 day
# Column.stocks                                                       Stocks in element
# Column.price_change_per_1d                           Price change in 1 day, 0.01 = 1%
# Column.price_change_abs                     Change of price / 1 day in currency value
# Column.close                                                              Close price
# Column.currency                                                     Currency of price
# Column.description                                             Description of element
# Column.dividends_yield_fwd            Dividend per share / share price FWD, 0.01 = 1%
# Column.dividends_yield_current            Dividend per share / share price, 0.01 = 1%
# Column.dividend_per_share                                        Dividended per share
# Column.earnings_per_share                                         Earning per 1 share
# Column.cnt_industries                                  Count of industries in element
# Column.market                                                 Market of stock trading
# Column.metric_cur                                                 Currency of metrics
# Column.industry                                                   Industry of element
# Column.market_country                                       Market country of element
# Column.market_cap                                               Market capitalization
# Column.el_name                                                        Name of element
# Column.price_vs_bookratio           Price of share / Book ratio of company, 0.01 = 1%
# Column.price_vs_earnings_per_share                        Price / earning per 1 share
# Column.price_dec_len                                         Price decimal max lenght
# Column.sector                                                       Sector of element
# Column.type                                                           Type of element
# Column.volume                                                Trading volume per 1 day
#
#                                     Need percent convert  \
# ENUM
# Column.TradedCap                                   False
# Column.stocks                                      False
# Column.price_change_per_1d                          True
# Column.price_change_abs                            False
# Column.close                                       False
# Column.currency                                    False
# Column.description                                 False
# Column.dividends_yield_fwd                          True
# Column.dividends_yield_current                      True
# Column.dividend_per_share                          False
# Column.earnings_per_share                          False
# Column.cnt_industries                              False
# Column.market                                      False
# Column.metric_cur                                  False
# Column.industry                                    False
# Column.market_country                              False
# Column.market_cap                                  False
# Column.el_name                                     False
# Column.price_vs_bookratio                          False
# Column.price_vs_earnings_per_share                 False
# Column.price_dec_len                               False
# Column.sector                                      False
# Column.type                                        False
# Column.volume                                      False
#
#                                                   Allowed for  \
# ENUM
# Column.TradedCap                                      [stock]
# Column.stocks                              [industry, sector]
# Column.price_change_per_1d          [industry, sector, stock]
# Column.price_change_abs                               [stock]
# Column.close                                          [stock]
# Column.currency                                       [stock]
# Column.description                  [industry, sector, stock]
# Column.dividends_yield_fwd          [industry, sector, stock]
# Column.dividends_yield_current                        [stock]
# Column.dividend_per_share                             [stock]
# Column.earnings_per_share                             [stock]
# Column.cnt_industries                                [sector]
# Column.market                                         [stock]
# Column.metric_cur                   [industry, sector, stock]
# Column.industry                                       [stock]
# Column.market_country                      [industry, sector]
# Column.market_cap                   [industry, sector, stock]
# Column.el_name                      [industry, sector, stock]
# Column.price_vs_bookratio                             [stock]
# Column.price_vs_earnings_per_share                    [stock]
# Column.price_dec_len                                  [stock]
# Column.sector                               [industry, stock]
# Column.type                         [industry, sector, stock]
# Column.volume                       [industry, sector, stock]
#
#                                                                      Allowed for enum
# ENUM
# Column.TradedCap                                                      [ColType.STOCK]
# Column.stocks                                      [ColType.INDUSTRY, ColType.SECTOR]
# Column.price_change_per_1d          [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.price_change_abs                                               [ColType.STOCK]
# Column.close                                                          [ColType.STOCK]
# Column.currency                                                       [ColType.STOCK]
# Column.description                  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.dividends_yield_fwd          [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.dividends_yield_current                                        [ColType.STOCK]
# Column.dividend_per_share                                             [ColType.STOCK]
# Column.earnings_per_share                                             [ColType.STOCK]
# Column.cnt_industries                                                [ColType.SECTOR]
# Column.market                                                         [ColType.STOCK]
# Column.metric_cur                   [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.industry                                                       [ColType.STOCK]
# Column.market_country                              [ColType.INDUSTRY, ColType.SECTOR]
# Column.market_cap                   [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.el_name                      [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.price_vs_bookratio                                             [ColType.STOCK]
# Column.price_vs_earnings_per_share                                    [ColType.STOCK]
# Column.price_dec_len                                                  [ColType.STOCK]
# Column.sector                                       [ColType.INDUSTRY, ColType.STOCK]
# Column.type                         [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# Column.volume                       [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]

# %% [markdown]
# ## Get area info

# %%
from src.client.usa_stock_market.sector_and_industry import get_sectors, get_industries, Column

# %%
sector_response = get_sectors([Column.el_name, Column.stocks,Column.market_cap,Column.type,Column.description])
print(sector_response.total_count)
sector_response.loaded_df
# Out:
# 02:19:30 DEBUG post_scan: json_dict: {'columns': ['name', 'basic_elements', 'market_cap_basic', 'type', 'description'], 'filter': [{'left': 'name', 'operation': 'nempty'}, {'left': 'typespecs', 'operation': 'has_none_of', 'right': 'preferred'}], 'ignore_unknown_fields': False, 'options': {'lang': 'en'}, 'range': [0, 1000000000], 'sort': {'sortBy': 'name', 'sortOrder': 'asc'}, 'markets': ['america'], 'symbols': {'query': {'types': ['sector']}, 'tickers': []}}
# 02:19:30 DEBUG post_scan: Request payload: {"columns": ["name", "basic_elements", "market_cap_basic", "type", "description"], "filter": [{"left": "name", "operation": "nempty"}, {"left": "typespecs", "operation": "has_none_of", "right": "preferred"}], "ignore_unknown_fields": false, "options": {"lang": "en"}, "range": [0, 1000000000], "sort": {"sortBy": "name", "sortOrder": "asc"}, "markets": ["america"], "symbols": {"query": {"types": ["sector"]}, "tickers": []}}
# 02:19:30 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): scanner.tradingview.com:443
# 02:19:30 DEBUG urllib3.connectionpool: https://scanner.tradingview.com:443 "POST /america/scan HTTP/1.1" 200 None
# 20
#                                                     Name  Stocks  \
# Id
# SECTOR_US:COMMERCIAL.SERVICES        commercial-services     256
# SECTOR_US:COMMUNICATIONS                  communications      50
# SECTOR_US:CONSUMER.DURABLES            consumer-durables     160
# SECTOR_US:CONSUMER.NON.DURABLES    consumer-non-durables     165
# SECTOR_US:CONSUMER.SERVICES            consumer-services     240
# SECTOR_US:DISTRIBUTION.SERVICES    distribution-services      84
# SECTOR_US:ELECTRONIC.TECHNOLOGY    electronic-technology     349
# SECTOR_US:ENERGY.MINERALS                energy-minerals     125
# SECTOR_US:FINANCE                                finance    1688
# SECTOR_US:HEALTH.SERVICES                health-services      95
# SECTOR_US:HEALTH.TECHNOLOGY            health-technology    1073
# SECTOR_US:INDUSTRIAL.SERVICES        industrial-services     135
# SECTOR_US:MISCELLANEOUS                    miscellaneous    3547
# SECTOR_US:NON.ENERGY.MINERALS        non-energy-minerals     169
# SECTOR_US:PROCESS.INDUSTRIES          process-industries     175
# SECTOR_US:PRODUCER.MANUFACTURING  producer-manufacturing     295
# SECTOR_US:RETAIL.TRADE                      retail-trade     197
# SECTOR_US:TECHNOLOGY.SERVICES        technology-services     628
# SECTOR_US:TRANSPORTATION                  transportation     145
# SECTOR_US:UTILITIES                            utilities     117
#
#                                     Market cap    Type             Description
# Id
# SECTOR_US:COMMERCIAL.SERVICES     1.752813e+12  sector     Commercial Services
# SECTOR_US:COMMUNICATIONS          8.388858e+11  sector          Communications
# SECTOR_US:CONSUMER.DURABLES       1.824705e+12  sector       Consumer Durables
# SECTOR_US:CONSUMER.NON.DURABLES   2.994216e+12  sector   Consumer Non-Durables
# SECTOR_US:CONSUMER.SERVICES       2.065907e+12  sector       Consumer Services
# SECTOR_US:DISTRIBUTION.SERVICES   5.080896e+11  sector   Distribution Services
# SECTOR_US:ELECTRONIC.TECHNOLOGY   8.474899e+12  sector   Electronic Technology
# SECTOR_US:ENERGY.MINERALS         2.613179e+12  sector         Energy Minerals
# SECTOR_US:FINANCE                 9.066061e+12  sector                 Finance
# SECTOR_US:HEALTH.SERVICES         1.018988e+12  sector         Health Services
# SECTOR_US:HEALTH.TECHNOLOGY       6.048808e+12  sector       Health Technology
# SECTOR_US:INDUSTRIAL.SERVICES     8.751368e+11  sector     Industrial Services
# SECTOR_US:MISCELLANEOUS           2.092222e+11  sector           Miscellaneous
# SECTOR_US:NON.ENERGY.MINERALS     1.100613e+12  sector     Non-Energy Minerals
# SECTOR_US:PROCESS.INDUSTRIES      1.103126e+12  sector      Process Industries
# SECTOR_US:PRODUCER.MANUFACTURING  1.912552e+12  sector  Producer Manufacturing
# SECTOR_US:RETAIL.TRADE            3.911584e+12  sector            Retail Trade
# SECTOR_US:TECHNOLOGY.SERVICES     1.158321e+13  sector     Technology Services
# SECTOR_US:TRANSPORTATION          1.185619e+12  sector          Transportation
# SECTOR_US:UTILITIES               1.475843e+12  sector               Utilities

# %%
industry_response = get_industries()
print(industry_response.total_count)
industry_response.loaded_df
# Out:
# 02:19:30 DEBUG post_scan: json_dict: {'columns': ['fundamental_currency_code', 'volume', 'change', 'market_cap_basic', 'type', 'description', 'dividends_yield', 'name', 'market', 'basic_elements', 'sector'], 'filter': [{'left': 'name', 'operation': 'nempty'}, {'left': 'typespecs', 'operation': 'has_none_of', 'right': 'preferred'}], 'ignore_unknown_fields': False, 'options': {'lang': 'en'}, 'range': [0, 1000000000], 'sort': {'sortBy': 'name', 'sortOrder': 'asc'}, 'markets': ['america'], 'symbols': {'query': {'types': ['industry']}, 'tickers': []}}
# 02:19:30 DEBUG post_scan: Request payload: {"columns": ["fundamental_currency_code", "volume", "change", "market_cap_basic", "type", "description", "dividends_yield", "name", "market", "basic_elements", "sector"], "filter": [{"left": "name", "operation": "nempty"}, {"left": "typespecs", "operation": "has_none_of", "right": "preferred"}], "ignore_unknown_fields": false, "options": {"lang": "en"}, "range": [0, 1000000000], "sort": {"sortBy": "name", "sortOrder": "asc"}, "markets": ["america"], "symbols": {"query": {"types": ["industry"]}, "tickers": []}}
# 02:19:30 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): scanner.tradingview.com:443
# 02:19:30 DEBUG urllib3.connectionpool: https://scanner.tradingview.com:443 "POST /america/scan HTTP/1.1" 200 None
# 129
#                                                    Metric currency  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...             USD
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...             USD
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...             USD
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                USD
# INDUSTRY_US:TRANSPORTATION.AIRLINES                            USD
# ...                                                            ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                            USD
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...             USD
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                          USD
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...             USD
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...             USD
#
#                                                      Volume / 1D  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...  2.877037e+06
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...  4.233118e+06
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...  3.880067e+06
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS     6.193251e+06
# INDUSTRY_US:TRANSPORTATION.AIRLINES                 7.479622e+06
# ...                                                          ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                 1.204152e+06
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  3.371367e+06
# INDUSTRY_US:UTILITIES.WATER.UTILITIES               2.033672e+06
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...  2.260908e+06
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...  2.258293e+07
#
#                                                     Price change/1D mult  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...             -0.003810
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...              0.001799
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...              0.008307
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                -0.006766
# INDUSTRY_US:TRANSPORTATION.AIRLINES                             0.001846
# ...                                                                  ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                            -0.005014
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...             -0.002026
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                           0.002969
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...             -0.003689
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...             -0.005490
#
#                                                       Market cap      Type  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...  5.378031e+10  industry
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...  9.461544e+11  industry
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...  7.843124e+10  industry
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS     2.782862e+11  industry
# INDUSTRY_US:TRANSPORTATION.AIRLINES                 1.266055e+11  industry
# ...                                                          ...       ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                 1.467997e+11  industry
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  4.345543e+11  industry
# INDUSTRY_US:UTILITIES.WATER.UTILITIES               6.102519e+10  industry
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...  2.165110e+11  industry
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...  6.790719e+11  industry
#
#                                                                            Description  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...      Advertising/Marketing Services
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...                 Aerospace & Defense
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...    Agricultural Commodities/Milling
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                   Air Freight/Couriers
# INDUSTRY_US:TRANSPORTATION.AIRLINES                                           Airlines
# ...                                                                                ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                                           Trucking
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  Trucks/Construction/Farm Machinery
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                                  Water Utilities
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...              Wholesale Distributors
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...         Wireless Telecommunications
#
#                                                     Dividend yield Mult FWD  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...                 0.028805
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...                 0.014315
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...                 0.025484
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                    0.026477
# INDUSTRY_US:TRANSPORTATION.AIRLINES                                0.006436
# ...                                                                     ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                                0.007198
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...                 0.016133
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                              0.020781
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...                 0.020423
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...                 0.041592
#
#                                                                                   Name  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...      advertising-marketing-services
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...                   aerospace-defense
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...    agricultural-commodities-milling
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                   air-freight-couriers
# INDUSTRY_US:TRANSPORTATION.AIRLINES                                           airlines
# ...                                                                                ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                                           trucking
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  trucks-construction-farm-machinery
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                                  water-utilities
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...              wholesale-distributors
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...         wireless-telecommunications
#
#                                                    Market country  Stocks  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...        america      36
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...        america      64
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...        america      32
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS           america      19
# INDUSTRY_US:TRANSPORTATION.AIRLINES                       america      22
# ...                                                           ...     ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                       america      22
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...        america      37
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                     america      14
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...        america      52
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...        america      22
#
#                                                                     Sector
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...     Commercial Services
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...   Electronic Technology
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...      Process Industries
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS             Transportation
# INDUSTRY_US:TRANSPORTATION.AIRLINES                         Transportation
# ...                                                                    ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                         Transportation
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  Producer Manufacturing
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                            Utilities
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...   Distribution Services
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...          Communications
#
# [129 rows x 11 columns]

# %% [markdown]
# ## Get stock info

# %%
from src.client.usa_stock_market.stock import get_stock_by_series

# %%
sector_response.loaded_df.loc["SECTOR_US:HEALTH.SERVICES"]
# Out:
# Name                health-services
# Stocks                           95
# Market cap     1018987935885.907349
# Type                         sector
# Description         Health Services
# Name: SECTOR_US:HEALTH.SERVICES, dtype: object

# %%
from src.api.request_context import RequestContext,Filter

# %%
request_context = RequestContext().add_filter(Filter(Column.dividends_yield_fwd.value, Filter.CompareFunc.gt, 0))
get_stock_by_series(sector_response.loaded_df.loc["SECTOR_US:HEALTH.SERVICES"],
                                  [Column.el_name, Column.dividends_yield_fwd, Column.dividends_yield_current, Column.earnings_per_share, Column.price_vs_earnings_per_share, Column.price_vs_bookratio],
                                  request_context).loaded_df
# Out:
# 02:19:30 DEBUG post_scan: json_dict: {'columns': ['name', 'dividends_yield', 'dividends_yield_current', 'earnings_per_share_basic_ttm', 'price_earnings_ttm', 'price_book_fq'], 'filter': [{'left': 'name', 'operation': 'nempty'}, {'left': 'typespecs', 'operation': 'has_none_of', 'right': 'preferred'}, {'left': 'dividends_yield', 'operation': 'greater', 'right': 0}, {'left': 'sector', 'operation': 'equal', 'right': 'Health Services'}], 'ignore_unknown_fields': False, 'options': {'lang': 'en'}, 'range': [0, 1000000000], 'sort': {'sortBy': 'name', 'sortOrder': 'asc'}, 'markets': ['america']}
# 02:19:30 DEBUG post_scan: Request payload: {"columns": ["name", "dividends_yield", "dividends_yield_current", "earnings_per_share_basic_ttm", "price_earnings_ttm", "price_book_fq"], "filter": [{"left": "name", "operation": "nempty"}, {"left": "typespecs", "operation": "has_none_of", "right": "preferred"}, {"left": "dividends_yield", "operation": "greater", "right": 0}, {"left": "sector", "operation": "equal", "right": "Health Services"}], "ignore_unknown_fields": false, "options": {"lang": "en"}, "range": [0, 1000000000], "sort": {"sortBy": "name", "sortOrder": "asc"}, "markets": ["america"]}
# 02:19:30 DEBUG urllib3.connectionpool: Starting new HTTPS connection (1): scanner.tradingview.com:443
# 02:19:31 DEBUG urllib3.connectionpool: https://scanner.tradingview.com:443 "POST /america/scan HTTP/1.1" 200 None
#               Name  Dividend yield Mult FWD  Dividend yield Mult TTM  \
# Id
# OTC:BDUUF    BDUUF                 0.020870                 0.020870
# NYSE:BKDT     BKDT                 0.056275                 0.000000
# NYSE:CHE       CHE                 0.002781                 0.002781
# NYSE:CI         CI                 0.018302                 0.017074
# NYSE:DGX       DGX                 0.020491                 0.019408
# NYSE:EHC       EHC                 0.009219                 0.011217
# NYSE:ELV       ELV                 0.013357                 0.012003
# NASDAQ:ENSG   ENSG                 0.002433                 0.002380
# OTC:EXETF    EXETF                 0.066390                 0.066390
# NYSE:FMS       FMS                 0.017607                 0.017621
# NYSE:HCA       HCA                 0.008274                 0.007860
# NYSE:HUM       HUM                 0.007943                 0.007287
# NYSE:LH         LH                 0.012294                 0.012293
# OTC:LTGHY    LTGHY                 0.014196                 0.014531
# OTC:LWSCF    LWSCF                 0.081391                 0.081391
# OTC:MFCSF    MFCSF                 0.039753                 0.039753
# OTC:MRCHF    MRCHF                 0.045754                 0.045754
# AMEX:NHC       NHC                 0.038200                 0.036905
# NASDAQ:NRC     NRC                 0.010619                 0.015929
# NASDAQ:PINC   PINC                 0.030011                 0.030011
# OTC:PMCUF    PMCUF                 0.003633                 0.003633
# NASDAQ:PMD     PMD                 0.060475                 0.060475
# OTC:RMYHY    RMYHY                 0.014361                 0.014405
# OTC:RYHTY    RYHTY                 0.027019                 0.027024
# NYSE:SEM       SEM                 0.017117                 0.017117
# OTC:SEMHF    SEMHF                 0.017992                 0.017992
# OTC:SKHCF    SKHCF                 0.029085                 0.029085
# OTC:SKHHY    SKHHY                 0.025773                 0.025763
# OTC:SMMNY    SMMNY                 0.011199                 0.011201
# NYSE:UHS       UHS                 0.005383                 0.005383
# NYSE:UNH       UNH                 0.016402                 0.014395
# NYSE:USPH     USPH                 0.014947                 0.014600
#
#              BasicEarningPerShare  Price/EarningPerShare  Price/BookRatio
# Id
# OTC:BDUUF                0.023227              31.652848         4.282654
# NYSE:BKDT               -0.929000                    NaN        21.464845
# NYSE:CHE                16.052800              34.407100         9.290597
# NYSE:CI                 22.219300              12.259500         1.789905
# NYSE:DGX                 6.869600              20.480236         2.565818
# NYSE:EHC                 2.716100              24.207707         4.713418
# NYSE:ELV                25.983200              17.242774         2.813240
# NASDAQ:ENSG              4.243100              22.843130         4.010101
# OTC:EXETF                0.024992             400.062823         6.227440
# NYSE:FMS                 1.061400              22.206520         0.920669
# NYSE:HCA                20.338500              14.540642              NaN
# NYSE:HUM                24.734500              18.110038         3.358976
# NYSE:LH                 11.064700              21.287016         2.007090
# OTC:LTGHY                0.243200              20.165289         1.549600
# OTC:LWSCF               -0.159193                    NaN         2.040961
# OTC:MFCSF                0.252209              38.291612         1.917278
# OTC:MRCHF                2.073876               9.548879         0.997709
# AMEX:NHC                 1.228900              50.366868         1.079119
# NASDAQ:NRC               1.219600              37.262984        14.891984
# NASDAQ:PINC              1.547200              18.277393         1.424554
# OTC:PMCUF                0.332101             142.686475        62.033171
# NASDAQ:PMD              -0.265000                    NaN         2.589630
# OTC:RMYHY                0.226200              42.294066         3.360984
# OTC:RYHTY                1.494600              13.374816         0.938742
# NYSE:SEM                 1.405800              20.778205         3.173841
# OTC:SEMHF                1.466395              39.075422         3.413582
# OTC:SKHCF                1.454286              16.614764         2.236461
# OTC:SKHHY                1.498100              16.257813         2.259318
# OTC:SMMNY                0.695900              41.356517         3.420738
# NYSE:UHS                 9.505300              15.786287         1.734902
# NYSE:UNH                22.150100              20.969033         5.255223
# NYSE:USPH                2.161800              53.228791         4.725904
