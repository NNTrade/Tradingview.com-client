# %% [markdown]
# # USA stock market

# %%
from src.client.usa_stock_market.columns import all_columns, to_df, industry_column_dic, sector_column_dic, stock_column_dic

# %% [markdown]
# ## Columns

# %%
col_df = to_df(all_columns)
col_df
# Out:
#                 Output name                       Tech name  \
# 0      BasicEarningPerShare    earnings_per_share_basic_ttm
# 1        Change in Cur / 1D                      change_abs
# 2                     Close                           close
# 3                  Currency                        currency
# 4               Decimal Len                      pricescale
# 5               Description                     description
# 6   Dividend yield Mult FWD                 dividends_yield
# 7   Dividend yield Mult TTM         dividends_yield_current
# 8            Dividend/Share  dps_common_stock_prim_issue_fy
# 9                Industries                        elements
# 10                 Industry                        industry
# 11                   Market                          market
# 12               Market cap                market_cap_basic
# 13          Metric currency       fundamental_currency_code
# 14                     Name                            name
# 15     Price change/1D mult                          change
# 16          Price/BookRatio                   price_book_fq
# 17    Price/EarningPerShare              price_earnings_ttm
# 18                   Sector                          sector
# 19                   Stocks                  basic_elements
# 20                     Type                            type
# 21      Volume * Price / 1D                    Value.Traded
# 22              Volume / 1D                          volume
#
#                                           Description  Need percent convert  \
# 0                                 Earning per 1 share                 False
# 1           Change of price / 1 day in currency value                 False
# 2                                         Close price                 False
# 3                                   Currency of price                 False
# 4                            Price decimal max lenght                 False
# 5                              Description of element                 False
# 6     Dividend per share / share price FWD, 0.01 = 1%                  True
# 7         Dividend per share / share price, 0.01 = 1%                  True
# 8                                Dividended per share                 False
# 9                      Count of industries in element                 False
# 10                                Industry of element                 False
# 11                                  Market of element                 False
# 12                              Market capitalization                 False
# 13                                Currency of metrics                 False
# 14                                    Name of element                 False
# 15                   Price change in 1 day, 0.01 = 1%                  True
# 16  Price of share / Book ratio of company, 0.01 = 1%                 False
# 17                        Price / earning per 1 share                 False
# 18                                  Sector of element                 False
# 19                                  Stocks in element                 False
# 20                                    Type of element                 False
# 21                             Capital traded / 1 day                 False
# 22                           Trading volume per 1 day                 False
#
#                   Allowed for  \
# 0                     [stock]
# 1                     [stock]
# 2                     [stock]
# 3                     [stock]
# 4                     [stock]
# 5   [industry, sector, stock]
# 6   [industry, sector, stock]
# 7                     [stock]
# 8                     [stock]
# 9                    [sector]
# 10                    [stock]
# 11         [industry, sector]
# 12  [industry, sector, stock]
# 13  [industry, sector, stock]
# 14  [industry, sector, stock]
# 15  [industry, sector, stock]
# 16                    [stock]
# 17                    [stock]
# 18          [industry, stock]
# 19         [industry, sector]
# 20  [industry, sector, stock]
# 21                    [stock]
# 22  [industry, sector, stock]
#
#                                      Allowed for enum
# 0                                     [ColType.STOCK]
# 1                                     [ColType.STOCK]
# 2                                     [ColType.STOCK]
# 3                                     [ColType.STOCK]
# 4                                     [ColType.STOCK]
# 5   [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 6   [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 7                                     [ColType.STOCK]
# 8                                     [ColType.STOCK]
# 9                                    [ColType.SECTOR]
# 10                                    [ColType.STOCK]
# 11                 [ColType.INDUSTRY, ColType.SECTOR]
# 12  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 13  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 14  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 15  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 16                                    [ColType.STOCK]
# 17                                    [ColType.STOCK]
# 18                  [ColType.INDUSTRY, ColType.STOCK]
# 19                 [ColType.INDUSTRY, ColType.SECTOR]
# 20  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]
# 21                                    [ColType.STOCK]
# 22  [ColType.INDUSTRY, ColType.SECTOR, ColType.STOCK]

# %% [markdown]
# ## Get area info

# %%
from src.client.usa_stock_market.sector_and_industry import get_sectors, get_industries

# %%
sector_response = get_sectors(list(sector_column_dic.keys()))
print(sector_response.total_count)
sector_response.loaded_df
# Out:
# 20
#                                  Metric currency   Volume / 1D  \
# Id
# SECTOR_US:COMMERCIAL.SERVICES                USD  5.398060e+06
# SECTOR_US:COMMUNICATIONS                     USD  9.953151e+06
# SECTOR_US:CONSUMER.DURABLES                  USD  7.655848e+07
# SECTOR_US:CONSUMER.NON.DURABLES              USD  5.349555e+06
# SECTOR_US:CONSUMER.SERVICES                  USD  5.792559e+06
# SECTOR_US:DISTRIBUTION.SERVICES              USD  2.235475e+06
# SECTOR_US:ELECTRONIC.TECHNOLOGY              USD  3.484462e+07
# SECTOR_US:ENERGY.MINERALS                    USD  8.431530e+06
# SECTOR_US:FINANCE                            USD  4.322462e+06
# SECTOR_US:HEALTH.SERVICES                    USD  3.952891e+06
# SECTOR_US:HEALTH.TECHNOLOGY                  USD  3.739278e+06
# SECTOR_US:INDUSTRIAL.SERVICES                USD  3.447993e+06
# SECTOR_US:MISCELLANEOUS                      USD  3.294992e+05
# SECTOR_US:NON.ENERGY.MINERALS                USD  4.345407e+06
# SECTOR_US:PROCESS.INDUSTRIES                 USD  1.753502e+06
# SECTOR_US:PRODUCER.MANUFACTURING             USD  2.123549e+06
# SECTOR_US:RETAIL.TRADE                       USD  2.364990e+07
# SECTOR_US:TECHNOLOGY.SERVICES                USD  2.141518e+07
# SECTOR_US:TRANSPORTATION                     USD  6.196709e+06
# SECTOR_US:UTILITIES                          USD  3.250791e+06
#
#                                   Price change/1D mult    Market cap    Type  \
# Id
# SECTOR_US:COMMERCIAL.SERVICES                 0.013148  1.749333e+12  sector
# SECTOR_US:COMMUNICATIONS                      0.016077  8.416829e+11  sector
# SECTOR_US:CONSUMER.DURABLES                   0.008128  1.806143e+12  sector
# SECTOR_US:CONSUMER.NON.DURABLES               0.010474  2.977030e+12  sector
# SECTOR_US:CONSUMER.SERVICES                   0.007357  2.075627e+12  sector
# SECTOR_US:DISTRIBUTION.SERVICES               0.015339  5.054706e+11  sector
# SECTOR_US:ELECTRONIC.TECHNOLOGY               0.002985  8.516714e+12  sector
# SECTOR_US:ENERGY.MINERALS                     0.011893  2.604696e+12  sector
# SECTOR_US:FINANCE                             0.010386  9.090915e+12  sector
# SECTOR_US:HEALTH.SERVICES                     0.016286  1.032211e+12  sector
# SECTOR_US:HEALTH.TECHNOLOGY                   0.014296  6.029636e+12  sector
# SECTOR_US:INDUSTRIAL.SERVICES                 0.010987  8.838340e+11  sector
# SECTOR_US:MISCELLANEOUS                       0.006018  2.087625e+11  sector
# SECTOR_US:NON.ENERGY.MINERALS                 0.008983  1.092398e+12  sector
# SECTOR_US:PROCESS.INDUSTRIES                  0.010961  1.100222e+12  sector
# SECTOR_US:PRODUCER.MANUFACTURING              0.010766  1.914945e+12  sector
# SECTOR_US:RETAIL.TRADE                        0.011759  3.930677e+12  sector
# SECTOR_US:TECHNOLOGY.SERVICES                 0.019415  1.169297e+13  sector
# SECTOR_US:TRANSPORTATION                      0.016370  1.187710e+12  sector
# SECTOR_US:UTILITIES                           0.010101  1.468809e+12  sector
#
#                                              Description  \
# Id
# SECTOR_US:COMMERCIAL.SERVICES        Commercial Services
# SECTOR_US:COMMUNICATIONS                  Communications
# SECTOR_US:CONSUMER.DURABLES            Consumer Durables
# SECTOR_US:CONSUMER.NON.DURABLES    Consumer Non-Durables
# SECTOR_US:CONSUMER.SERVICES            Consumer Services
# SECTOR_US:DISTRIBUTION.SERVICES    Distribution Services
# SECTOR_US:ELECTRONIC.TECHNOLOGY    Electronic Technology
# SECTOR_US:ENERGY.MINERALS                Energy Minerals
# SECTOR_US:FINANCE                                Finance
# SECTOR_US:HEALTH.SERVICES                Health Services
# SECTOR_US:HEALTH.TECHNOLOGY            Health Technology
# SECTOR_US:INDUSTRIAL.SERVICES        Industrial Services
# SECTOR_US:MISCELLANEOUS                    Miscellaneous
# SECTOR_US:NON.ENERGY.MINERALS        Non-Energy Minerals
# SECTOR_US:PROCESS.INDUSTRIES          Process Industries
# SECTOR_US:PRODUCER.MANUFACTURING  Producer Manufacturing
# SECTOR_US:RETAIL.TRADE                      Retail Trade
# SECTOR_US:TECHNOLOGY.SERVICES        Technology Services
# SECTOR_US:TRANSPORTATION                  Transportation
# SECTOR_US:UTILITIES                            Utilities
#
#                                   Dividend yield Mult FWD  \
# Id
# SECTOR_US:COMMERCIAL.SERVICES                    0.007593
# SECTOR_US:COMMUNICATIONS                         0.042794
# SECTOR_US:CONSUMER.DURABLES                      0.010772
# SECTOR_US:CONSUMER.NON.DURABLES                  0.027300
# SECTOR_US:CONSUMER.SERVICES                      0.010324
# SECTOR_US:DISTRIBUTION.SERVICES                  0.012689
# SECTOR_US:ELECTRONIC.TECHNOLOGY                  0.008878
# SECTOR_US:ENERGY.MINERALS                        0.065824
# SECTOR_US:FINANCE                                0.026835
# SECTOR_US:HEALTH.SERVICES                        0.012023
# SECTOR_US:HEALTH.TECHNOLOGY                      0.015617
# SECTOR_US:INDUSTRIAL.SERVICES                    0.041533
# SECTOR_US:MISCELLANEOUS                          0.070894
# SECTOR_US:NON.ENERGY.MINERALS                    0.036898
# SECTOR_US:PROCESS.INDUSTRIES                     0.024298
# SECTOR_US:PRODUCER.MANUFACTURING                 0.014097
# SECTOR_US:RETAIL.TRADE                           0.009179
# SECTOR_US:TECHNOLOGY.SERVICES                    0.004921
# SECTOR_US:TRANSPORTATION                         0.019814
# SECTOR_US:UTILITIES                              0.035241
#
#                                                     Name   Market  Stocks  \
# Id
# SECTOR_US:COMMERCIAL.SERVICES        commercial-services  america     253
# SECTOR_US:COMMUNICATIONS                  communications  america      50
# SECTOR_US:CONSUMER.DURABLES            consumer-durables  america     159
# SECTOR_US:CONSUMER.NON.DURABLES    consumer-non-durables  america     165
# SECTOR_US:CONSUMER.SERVICES            consumer-services  america     241
# SECTOR_US:DISTRIBUTION.SERVICES    distribution-services  america      84
# SECTOR_US:ELECTRONIC.TECHNOLOGY    electronic-technology  america     349
# SECTOR_US:ENERGY.MINERALS                energy-minerals  america     123
# SECTOR_US:FINANCE                                finance  america    1696
# SECTOR_US:HEALTH.SERVICES                health-services  america      95
# SECTOR_US:HEALTH.TECHNOLOGY            health-technology  america    1074
# SECTOR_US:INDUSTRIAL.SERVICES        industrial-services  america     136
# SECTOR_US:MISCELLANEOUS                    miscellaneous  america    3543
# SECTOR_US:NON.ENERGY.MINERALS        non-energy-minerals  america     169
# SECTOR_US:PROCESS.INDUSTRIES          process-industries  america     174
# SECTOR_US:PRODUCER.MANUFACTURING  producer-manufacturing  america     297
# SECTOR_US:RETAIL.TRADE                      retail-trade  america     197
# SECTOR_US:TECHNOLOGY.SERVICES        technology-services  america     628
# SECTOR_US:TRANSPORTATION                  transportation  america     145
# SECTOR_US:UTILITIES                            utilities  america     117
#
#                                   Industries
# Id
# SECTOR_US:COMMERCIAL.SERVICES              5
# SECTOR_US:COMMUNICATIONS                   3
# SECTOR_US:CONSUMER.DURABLES                8
# SECTOR_US:CONSUMER.NON.DURABLES            9
# SECTOR_US:CONSUMER.SERVICES               10
# SECTOR_US:DISTRIBUTION.SERVICES            4
# SECTOR_US:ELECTRONIC.TECHNOLOGY            9
# SECTOR_US:ENERGY.MINERALS                  4
# SECTOR_US:FINANCE                         14
# SECTOR_US:HEALTH.SERVICES                  4
# SECTOR_US:HEALTH.TECHNOLOGY                5
# SECTOR_US:INDUSTRIAL.SERVICES              5
# SECTOR_US:MISCELLANEOUS                    2
# SECTOR_US:NON.ENERGY.MINERALS              6
# SECTOR_US:PROCESS.INDUSTRIES               8
# SECTOR_US:PRODUCER.MANUFACTURING           9
# SECTOR_US:RETAIL.TRADE                    10
# SECTOR_US:TECHNOLOGY.SERVICES              4
# SECTOR_US:TRANSPORTATION                   6
# SECTOR_US:UTILITIES                        4

# %%
industry_response = get_industries()
print(industry_response.total_count)
industry_response.loaded_df
# Out:
# 129
#                                                    Metric currency  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...             USD
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...             USD
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...             USD
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                USD
# INDUSTRY_US:TRANSPORTATION.AIRLINES                            USD
# ...                                                            ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                            USD
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...             USD
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                          USD
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...             USD
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...             USD
#
#                                                      Volume / 1D  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...  1.521477e+06
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...  2.246914e+06
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...  2.508276e+06
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS     3.248859e+06
# INDUSTRY_US:TRANSPORTATION.AIRLINES                 7.733223e+06
# ...                                                          ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                 8.668967e+05
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  1.908414e+06
# INDUSTRY_US:UTILITIES.WATER.UTILITIES               7.617847e+05
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...  1.140547e+06
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...  1.202556e+07
#
#                                                     Price change/1D mult  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...              0.010686
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...              0.012309
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...              0.006454
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                 0.022179
# INDUSTRY_US:TRANSPORTATION.AIRLINES                             0.007364
# ...                                                                  ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                             0.011567
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...              0.015331
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                           0.011267
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...              0.015119
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...              0.018164
#
#                                                       Market cap      Type  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...  5.396604e+10  industry
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...  9.449724e+11  industry
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...  7.778627e+10  industry
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS     2.792844e+11  industry
# INDUSTRY_US:TRANSPORTATION.AIRLINES                 1.261264e+11  industry
# ...                                                          ...       ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                 1.475209e+11  industry
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  4.354631e+11  industry
# INDUSTRY_US:UTILITIES.WATER.UTILITIES               6.086951e+10  industry
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...  2.173879e+11  industry
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...  6.822752e+11  industry
#
#                                                                            Description  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...      Advertising/Marketing Services
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...                 Aerospace & Defense
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...    Agricultural Commodities/Milling
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                   Air Freight/Couriers
# INDUSTRY_US:TRANSPORTATION.AIRLINES                                           Airlines
# ...                                                                                ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                                           Trucking
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  Trucks/Construction/Farm Machinery
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                                  Water Utilities
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...              Wholesale Distributors
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...         Wireless Telecommunications
#
#                                                     Dividend yield Mult FWD  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...                 0.029031
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...                 0.014503
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...                 0.025913
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                    0.027005
# INDUSTRY_US:TRANSPORTATION.AIRLINES                                0.004456
# ...                                                                     ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                                0.007198
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...                 0.016351
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                              0.021075
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...                 0.020585
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...                 0.041847
#
#                                                                                   Name  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...      advertising-marketing-services
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...                   aerospace-defense
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...    agricultural-commodities-milling
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS                   air-freight-couriers
# INDUSTRY_US:TRANSPORTATION.AIRLINES                                           airlines
# ...                                                                                ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                                           trucking
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  trucks-construction-farm-machinery
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                                  water-utilities
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...              wholesale-distributors
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...         wireless-telecommunications
#
#                                                      Market  Stocks  \
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...  america      36
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...  america      64
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...  america      32
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS     america      19
# INDUSTRY_US:TRANSPORTATION.AIRLINES                 america      22
# ...                                                     ...     ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                 america      22
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  america      37
# INDUSTRY_US:UTILITIES.WATER.UTILITIES               america      14
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...  america      52
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...  america      22
#
#                                                                     Sector
# Id
# INDUSTRY_US:COMMERCIAL.SERVICES.ADVERTISING.MAR...     Commercial Services
# INDUSTRY_US:ELECTRONIC.TECHNOLOGY.AEROSPACE.DEF...   Electronic Technology
# INDUSTRY_US:PROCESS.INDUSTRIES.AGRICULTURAL.COM...      Process Industries
# INDUSTRY_US:TRANSPORTATION.AIR.FREIGHT.COURIERS             Transportation
# INDUSTRY_US:TRANSPORTATION.AIRLINES                         Transportation
# ...                                                                    ...
# INDUSTRY_US:TRANSPORTATION.TRUCKING                         Transportation
# INDUSTRY_US:PRODUCER.MANUFACTURING.TRUCKS.CONST...  Producer Manufacturing
# INDUSTRY_US:UTILITIES.WATER.UTILITIES                            Utilities
# INDUSTRY_US:DISTRIBUTION.SERVICES.WHOLESALE.DIS...   Distribution Services
# INDUSTRY_US:COMMUNICATIONS.WIRELESS.TELECOMMUNI...          Communications
#
# [129 rows x 11 columns]

# %% [markdown]
# ## Get stock info

# %%
from src.client.usa_stock_market.stock import get_stock_by_series

# %%
get_stock_by_series(industry_response.loaded_df.iloc[0]).loaded_df.head(10)
# Out:
#             Metric currency  Volume / 1D  Price change/1D mult    Market cap  \
# Id
# OTC:AATV                USD          244              0.000000  1.728473e+07
# OTC:ACHN                USD         1250             -0.010526  2.819530e+07
# OTC:ADMQ                USD        45314             -0.026764  6.146086e+06
# NASDAQ:ADV              USD       409125              0.047619  7.131432e+08
# NASDAQ:ANTE             USD        10406             -0.100671  1.329629e+07
# OTC:APHD                USD         9500              2.658537  5.999700e+04
# OTC:ASPR                USD        34020              4.000000           NaN
# NASDAQ:ASST             USD      1239521              0.068354  2.882474e+07
# NASDAQ:BAOS             USD        92902              0.046036  1.247015e+07
# OTC:BCNN                USD      3497491             -0.078947  8.200868e+04
#
#               Type                            Description  \
# Id
# OTC:AATV     stock              Adaptive Ad Systems, Inc.
# OTC:ACHN     stock                           Achison Inc.
# OTC:ADMQ     stock                     ADM Endeavors Inc.
# NASDAQ:ADV   stock               Advantage Solutions Inc.
# NASDAQ:ANTE     dr                 AirNet Technology Inc.
# OTC:APHD     stock                   APOGEE 21 HLDGS INC.
# OTC:ASPR     stock                   ADSOUTH PARTNERS INC
# NASDAQ:ASST  stock                    Asset Entities Inc.
# NASDAQ:BAOS  stock  Baosheng Media Group Holdings Limited
# OTC:BCNN     stock                     Balincan USA, Inc.
#
#              Dividend yield Mult TTM  Dividend yield Mult FWD  \
# Id
# OTC:AATV                         0.0                      NaN
# OTC:ACHN                         0.0                      NaN
# OTC:ADMQ                         0.0                      NaN
# NASDAQ:ADV                       0.0                      NaN
# NASDAQ:ANTE                      0.0                      NaN
# OTC:APHD                         0.0                      NaN
# OTC:ASPR                         NaN                      NaN
# NASDAQ:ASST                      0.0                      NaN
# NASDAQ:BAOS                      0.0                      NaN
# OTC:BCNN                         0.0                      NaN
#
#              Price/BookRatio  Name   Close  Decimal Len Currency  \
# Id
# OTC:AATV            1.013086  AATV  0.3600        10000      USD
# OTC:ACHN                 NaN  ACHN  0.9400        10000      USD
# OTC:ADMQ            2.642008  ADMQ  0.0400        10000      USD
# NASDAQ:ADV          0.651252   ADV  2.2000          100      USD
# NASDAQ:ANTE         0.261302  ANTE  1.3400          100      USD
# OTC:APHD                 NaN  APHD  0.1500        10000      USD
# OTC:ASPR                 NaN  ASPR  0.0005        10000      USD
# NASDAQ:ASST         4.949914  ASST  2.1100          100      USD
# NASDAQ:BAOS         1.646710  BAOS  8.1800          100      USD
# OTC:BCNN                 NaN  BCNN  0.0035        10000      USD
#
#              Change in Cur / 1D  Volume * Price / 1D  Price/EarningPerShare  \
# Id
# OTC:AATV                 0.0000         8.784000e+01               6.857143
# OTC:ACHN                -0.0100         1.175000e+03                    NaN
# OTC:ADMQ                -0.0011         1.812560e+03                    NaN
# NASDAQ:ADV               0.1000         9.000750e+05                    NaN
# NASDAQ:ANTE             -0.1500         1.394404e+04                    NaN
# OTC:APHD                 0.1090         1.425000e+03               0.558867
# OTC:ASPR                 0.0004         1.701000e+01                    NaN
# NASDAQ:ASST              0.1350         2.615389e+06                    NaN
# NASDAQ:BAOS              0.3600         7.599384e+05                    NaN
# OTC:BCNN                -0.0003         1.224122e+04                    NaN
#
#              BasicEarningPerShare  Dividend/Share               Sector  \
# Id
# OTC:AATV                   0.0525             0.0  Commercial Services
# OTC:ACHN                  -0.0011             0.0  Commercial Services
# OTC:ADMQ                   0.0002             0.0  Commercial Services
# NASDAQ:ADV                -4.5255             0.0  Commercial Services
# NASDAQ:ANTE               -1.3513             0.0  Commercial Services
# OTC:APHD                   3.2506             0.0  Commercial Services
# OTC:ASPR                      NaN             NaN  Commercial Services
# NASDAQ:ASST               -0.1223             NaN  Commercial Services
# NASDAQ:BAOS               -2.1211             0.0  Commercial Services
# OTC:BCNN                  -1.2779             0.0  Commercial Services
#
#                                    Industry
# Id
# OTC:AATV     Advertising/Marketing Services
# OTC:ACHN     Advertising/Marketing Services
# OTC:ADMQ     Advertising/Marketing Services
# NASDAQ:ADV   Advertising/Marketing Services
# NASDAQ:ANTE  Advertising/Marketing Services
# OTC:APHD     Advertising/Marketing Services
# OTC:ASPR     Advertising/Marketing Services
# NASDAQ:ASST  Advertising/Marketing Services
# NASDAQ:BAOS  Advertising/Marketing Services
# OTC:BCNN     Advertising/Marketing Services
